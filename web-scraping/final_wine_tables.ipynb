# %%
# Dependencies and Setup
import pandas as pd

# %%
# File to Load (Remember to Change These)
wine_data_file = "Resources/wine-data.csv"
# File to Load (Remember to Change These)
wine_production_file = "Resources/wine-production.csv"
# File to Load (Remember to Change These)
wine_consumption_file= "Resources/wine-consumption.csv"
# File to Load (Remember to Change These)
world_temperature_file= "Resources/world_temperature.csv"

# %%
data_df = pd.read_csv(wine_data_file)
data_df
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# ...                                      ...     ...    ...
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province           region_1           region_2  \
# 0               California        Napa Valley               Napa
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# ...                    ...                ...                ...
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150928           Champagne          Champagne                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    variety                   winery
# 0       Cabernet Sauvignon                    Heitz
# 1            Tinta de Toro  Bodega Carmen Rodríguez
# 2          Sauvignon Blanc                 Macauley
# 3               Pinot Noir                    Ponzi
# 4       Provence red blend     Domaine de la Bégude
# ...                    ...                      ...
# 150925         White Blend    Feudi di San Gregorio
# 150926     Champagne Blend                H.Germain
# 150927         White Blend                Terredora
# 150928     Champagne Blend                   Gosset
# 150929        Pinot Grigio            Alois Lageder
#
# [150930 rows x 11 columns]

# %%
#drop null values ( previous amount of content : 150930 rows × 11 columns ..... current content : 39241 rows × 11 columns)
data_df.dropna()
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 8                8      US  This re-named vineyard was formerly bottled as...
# 9                9      US  The producer sources from two blocks of the vi...
# ...            ...     ...                                                ...
# 150889      150889      US  A bizarre style of wine. The aromas are Port-l...
# 150892      150892      US  A light, earthy wine, with violet, berry and t...
# 150914      150914      US  Old-gold in color, and thick and syrupy. The a...
# 150915      150915      US  Decades ago, Beringer’s then-winemaker Myron N...
# 150916      150916      US  An impressive wine that presents a full bouque...
#
#                           designation  points  price    province  \
# 0                   Martha's Vineyard      96  235.0  California
# 2       Special Selected Late Harvest      96   90.0  California
# 3                             Reserve      96   65.0      Oregon
# 8                              Silice      95   65.0      Oregon
# 9                Gap's Crown Vineyard      95   60.0  California
# ...                               ...     ...    ...         ...
# 150889                Lafond Vineyard      82   35.0  California
# 150892                        Coastal      82   10.0  California
# 150914    Late Harvest Cluster Select      94   25.0  California
# 150915                    Nightingale      93   30.0  California
# 150916                      J. Schram      93   65.0  California
#
#                   region_1                 region_2             variety  \
# 0              Napa Valley                     Napa  Cabernet Sauvignon
# 2           Knights Valley                   Sonoma     Sauvignon Blanc
# 3        Willamette Valley        Willamette Valley          Pinot Noir
# 8       Chehalem Mountains        Willamette Valley          Pinot Noir
# 9             Sonoma Coast                   Sonoma          Pinot Noir
# ...                    ...                      ...                 ...
# 150889   Santa Ynez Valley            Central Coast          Pinot Noir
# 150892          California         California Other              Merlot
# 150914     Anderson Valley  Mendocino/Lake Counties      White Riesling
# 150915         North Coast              North Coast         White Blend
# 150916         Napa Valley                     Napa     Champagne Blend
#
#              winery
# 0             Heitz
# 2          Macauley
# 3             Ponzi
# 8         Bergström
# 9         Blue Farm
# ...             ...
# 150889       Lafond
# 150892     Callaway
# 150914      Navarro
# 150915     Beringer
# 150916  Schramsberg
#
# [39241 rows x 11 columns]

# %%
# wine_production_file = "Resources/wine-production.csv"
wine_production = pd.read_csv(wine_data_file)
wine_production
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# ...                                      ...     ...    ...
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province           region_1           region_2  \
# 0               California        Napa Valley               Napa
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# ...                    ...                ...                ...
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150928           Champagne          Champagne                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    variety                   winery
# 0       Cabernet Sauvignon                    Heitz
# 1            Tinta de Toro  Bodega Carmen Rodríguez
# 2          Sauvignon Blanc                 Macauley
# 3               Pinot Noir                    Ponzi
# 4       Provence red blend     Domaine de la Bégude
# ...                    ...                      ...
# 150925         White Blend    Feudi di San Gregorio
# 150926     Champagne Blend                H.Germain
# 150927         White Blend                Terredora
# 150928     Champagne Blend                   Gosset
# 150929        Pinot Grigio            Alois Lageder
#
# [150930 rows x 11 columns]

# %%
#wine_consumption_file= "Resources/wine-consumption.csv"
wine_consumption = pd.read_csv(wine_data_file)
wine_consumption
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# ...                                      ...     ...    ...
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province           region_1           region_2  \
# 0               California        Napa Valley               Napa
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# ...                    ...                ...                ...
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150928           Champagne          Champagne                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    variety                   winery
# 0       Cabernet Sauvignon                    Heitz
# 1            Tinta de Toro  Bodega Carmen Rodríguez
# 2          Sauvignon Blanc                 Macauley
# 3               Pinot Noir                    Ponzi
# 4       Provence red blend     Domaine de la Bégude
# ...                    ...                      ...
# 150925         White Blend    Feudi di San Gregorio
# 150926     Champagne Blend                H.Germain
# 150927         White Blend                Terredora
# 150928     Champagne Blend                   Gosset
# 150929        Pinot Grigio            Alois Lageder
#
# [150930 rows x 11 columns]

# %%
#world_temperature_file= "Resources/world_temperature.csv"
world_temperature = pd.read_csv(wine_data_file)
world_temperature
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# ...                                      ...     ...    ...
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province           region_1           region_2  \
# 0               California        Napa Valley               Napa
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# ...                    ...                ...                ...
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150928           Champagne          Champagne                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    variety                   winery
# 0       Cabernet Sauvignon                    Heitz
# 1            Tinta de Toro  Bodega Carmen Rodríguez
# 2          Sauvignon Blanc                 Macauley
# 3               Pinot Noir                    Ponzi
# 4       Provence red blend     Domaine de la Bégude
# ...                    ...                      ...
# 150925         White Blend    Feudi di San Gregorio
# 150926     Champagne Blend                H.Germain
# 150927         White Blend                Terredora
# 150928     Champagne Blend                   Gosset
# 150929        Pinot Grigio            Alois Lageder
#
# [150930 rows x 11 columns]

# %%
#create a regions dataframe ( Region 1, Province) from "wine_data_file"
regions = pd.read_csv(wine_data_file)
regions.drop([ 
              'country', 
              'description',
              'designation',
              'points',
              'price',
              'region_2',
              'variety',
              'winery'
             ], axis=1)
# Out:
#         Unnamed: 0            province           region_1
# 0                0          California        Napa Valley
# 1                1      Northern Spain               Toro
# 2                2          California     Knights Valley
# 3                3              Oregon  Willamette Valley
# 4                4            Provence             Bandol
# ...            ...                 ...                ...
# 150925      150925      Southern Italy  Fiano di Avellino
# 150926      150926           Champagne          Champagne
# 150927      150927      Southern Italy  Fiano di Avellino
# 150928      150928           Champagne          Champagne
# 150929      150929  Northeastern Italy         Alto Adige
#
# [150930 rows x 3 columns]

# %%
# Create a dataframe of provinces (Country , Province) from "wine_data_file"
provinces = pd.read_csv(wine_data_file)
provinces.drop([  
              'description',
              'designation',
              'points',
              'price',
              'region_1',
              'region_2',
              'variety',
              'winery'
             ], axis=1)
# Out:
#         Unnamed: 0 country            province
# 0                0      US          California
# 1                1   Spain      Northern Spain
# 2                2      US          California
# 3                3      US              Oregon
# 4                4  France            Provence
# ...            ...     ...                 ...
# 150925      150925   Italy      Southern Italy
# 150926      150926  France           Champagne
# 150927      150927   Italy      Southern Italy
# 150928      150928  France           Champagne
# 150929      150929   Italy  Northeastern Italy
#
# [150930 rows x 3 columns]

# %%
# includes region 1 and 2  -- final table to be called region 1 US from "wine_data_file"
region_US = pd.read_csv(wine_data_file)
region_US.drop (['description',
                 'designation',
                 'points',
                 'price',
                 'variety',
                 'winery',
                 'country',
                 'province',
                ], axis=1)
# Out:
#         Unnamed: 0           region_1           region_2
# 0                0        Napa Valley               Napa
# 1                1               Toro                NaN
# 2                2     Knights Valley             Sonoma
# 3                3  Willamette Valley  Willamette Valley
# 4                4             Bandol                NaN
# ...            ...                ...                ...
# 150925      150925  Fiano di Avellino                NaN
# 150926      150926          Champagne                NaN
# 150927      150927  Fiano di Avellino                NaN
# 150928      150928          Champagne                NaN
# 150929      150929         Alto Adige                NaN
#
# [150930 rows x 3 columns]

# %%
# # include country and country_code
# countries

# %%
#includes (description, designation, points, price, province, variety, winery) from "wine_data_file"
wine_data = pd.read_csv(wine_data_file)
wine_data.drop([
                'country',
                'region_1',
                'region_2',
                ], axis=1)
# Out:
#         Unnamed: 0                                        description  \
# 0                0  This tremendous 100% varietal wine hails from ...
# 1                1  Ripe aromas of fig, blackberry and cassis are ...
# 2                2  Mac Watson honors the memory of a wine once ma...
# 3                3  This spent 20 months in 30% new French oak, an...
# 4                4  This is the top wine from La Bégude, named aft...
# ...            ...                                                ...
# 150925      150925  Many people feel Fiano represents southern Ita...
# 150926      150926  Offers an intriguing nose with ginger, lime an...
# 150927      150927  This classic example comes from a cru vineyard...
# 150928      150928  A perfect salmon shade, with scents of peaches...
# 150929      150929  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# ...                                      ...     ...    ...
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province             variety                   winery
# 0               California  Cabernet Sauvignon                    Heitz
# 1           Northern Spain       Tinta de Toro  Bodega Carmen Rodríguez
# 2               California     Sauvignon Blanc                 Macauley
# 3                   Oregon          Pinot Noir                    Ponzi
# 4                 Provence  Provence red blend     Domaine de la Bégude
# ...                    ...                 ...                      ...
# 150925      Southern Italy         White Blend    Feudi di San Gregorio
# 150926           Champagne     Champagne Blend                H.Germain
# 150927      Southern Italy         White Blend                Terredora
# 150928           Champagne     Champagne Blend                   Gosset
# 150929  Northeastern Italy        Pinot Grigio            Alois Lageder
#
# [150930 rows x 8 columns]
