# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "Resources/wine-data.csv"
wine_data_df = pd.read_csv(csv_file)
wine_data_df.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
new_wine_data_df = wine_data_df[['country', 'points', 'price', 'province', 'variety']].copy()
new_wine_data_df.head()
# Out:
#   country  points  price        province             variety
# 0      US      96  235.0      California  Cabernet Sauvignon
# 1   Spain      96  110.0  Northern Spain       Tinta de Toro
# 2      US      96   90.0      California     Sauvignon Blanc
# 3      US      96   65.0          Oregon          Pinot Noir
# 4  France      95   66.0        Provence  Provence red blend

# %%
csv_file = "Resources/wine-production.csv"
wine_data_df = pd.read_csv(csv_file)
wine_data_df.head()
# Out:
#          country  wineProduction  wineProductionGallons     pop2020
# 0          Italy         4250000                1122731   60461.826
# 1         France         3641900                 962088   65273.511
# 2          Spain         3248000                 858030   46754.778
# 3  United States         2333900                 616551  331002.651
# 4      Australia         1369000                 361651   25499.884

# %%
#df1.merge(df2,on='name').merge(df3,on='name')
merged_df = wine_data_df.merge(new_wine_data_df, on='country')
merged_df
# Out:
#          country  wineProduction  wineProductionGallons    pop2020  points  \
# 0          Italy         4250000                1122731  60461.826      95
# 1          Italy         4250000                1122731  60461.826      90
# 2          Italy         4250000                1122731  60461.826      90
# 3          Italy         4250000                1122731  60461.826      90
# 4          Italy         4250000                1122731  60461.826      90
# ...          ...             ...                    ...        ...     ...
# 88505  Lithuania            4100                   1083   2722.289      84
# 88506  Lithuania            4100                   1083   2722.289      85
# 88507  Lithuania            4100                   1083   2722.289      84
# 88508  Lithuania            4100                   1083   2722.289      84
# 88509  Lithuania            4100                   1083   2722.289      84
#
#        price            province          variety
# ...

# %%
csv_file = "Resources/wine-consumption.csv"
wine_df = pd.read_csv(csv_file)
wine_new_df = wine_df.rename({'Entity': 'country'})
wine_new_df.head()
# Out:
#                 Entity Code  \
# 0              Albania  ALB
# 1              Algeria  DZA
# 2              Andorra  AND
# 3               Angola  AGO
# 4  Antigua and Barbuda  ATG
#
#    Indicator:Alcohol, consumption of pure alcohol by type of beverage (%) - Beverage Types:Wine
# 0                                               19.8
# 1                                               35.5
# 2                                               45.3
# 3                                               13.7
# 4                                               16.4

# %%
new_merged_df = wine_df.merge(merged_df, on='country')
new_merged_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-4170a4585c39> in <module>
# ----> 1 new_merged_df = wine_df.merge(merged_df, on='country')
#       2 new_merged_df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7282         from pandas.core.reshape.merge import merge
#    7283
# -> 7284         return merge(
#    7285             self,
#    7286             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# ...
